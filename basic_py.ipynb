# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusanl/Data-Scientist/blob/master/basic_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2];
y = [2, 3];

plt.plot(x, y);
## plt.grid = coloca as linhas da grade no gráfico
plt.grid();
plt.show();

# %%
x = [1, 2, 5];
y = [2, 3, 7];

title = "Gráfico de barras em Python!";
eixoX = "Eixo X";
eixoY = "Eixo Y";

## Titulo do Gráfico
plt.title("Gráfico de linhas em Python!");

## Legenda dos eixos
plt.xlabel("Eixo X");
plt.ylabel("Eixo Y");

## plt.plot = grafico de linhas
plt.plot(x, y);
plt.grid();
plt.show();

# %%
x = [1, 2, 3, 4, 5];
y = [2, 3, 7, 1, 0];

## Titulo do Gráfico
plt.title(title);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.bar = grafico de barras
plt.bar(x, y);
plt.show();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

## Titulo do Gráfico
plt.title(title);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.bar = grafico de barras
plt.bar(x1, y1, label = "Grupo 1");
plt.bar(x2, y2, label = "Grupo 2");

## plt.legend = coloca legenda no grafico
plt.legend();
plt.show();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

title1 = "Gráfico Scatterplot em Python!";

## Titulo do Gráfico
plt.title(title1);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.scatter = grafico scatterplot
## atributo color altera a cor dos pontos no grafico
plt.scatter(x1, y1, label = "Grupo 1", color = "red");
plt.scatter(x2, y2, label = "Grupo 2");

## grafico de linhas dentro do grafico scatterplot
plt.plot(x1, y1, color = "orange");
plt.plot(x2, y2);

## plt.legend = coloca legenda no grafico
plt.legend();
plt.grid();
plt.show();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

title1 = "Gráfico Scatterplot em Python!";

## Titulo do Gráfico
plt.title(title1);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.scatter = grafico scatterplot
## atributo color altera a cor dos pontos no grafico
## marker = altera o marcador no grafico
## s = altera o tamanho do marcador
## linestyle = altera o estilo da linha
plt.scatter(x1, y1, label = "Grupo 1", color = "red", marker = "^", s = 150);
plt.scatter(x2, y2, label = "Grupo 2", color = "green", marker = "X", s = 150);

## grafico de linhas dentro do grafico scatterplot
plt.plot(x1, y1, color = "orange", linestyle = ":");
plt.plot(x2, y2);
plt.grid();

## plt.legend = coloca legenda no grafico
plt.legend();
plt.show();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

title1 = "Gráfico Scatterplot em Python!";

## Titulo do Gráfico
plt.title(title1);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.scatter = grafico scatterplot
## atributo color altera a cor dos pontos no grafico
## marker = altera o marcador no grafico
## s = altera o tamanho do marcador
## linestyle = altera o estilo da linha
plt.scatter(x1, y1, label = "Grupo 1", color = "red", marker = "^", s = 150);
plt.scatter(x2, y2, label = "Grupo 2", color = "green", marker = "X", s = 150);

## grafico de linhas dentro do grafico scatterplot
## o atributo color aceita cores hexadecimais
plt.plot(x1, y1, color = "#080808", linestyle = ":");
plt.plot(x2, y2, color = "#000000", linestyle = "--");

## plt.legend = coloca legenda no grafico
plt.legend();
plt.grid();
plt.show();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

title1 = "Gráfico Scatterplot em Python!";

## Titulo do Gráfico
plt.title(title1);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.scatter = grafico scatterplot
## atributo color altera a cor dos pontos no grafico
## marker = altera o marcador no grafico
## s = altera o tamanho do marcador
## linestyle = altera o estilo da linha
plt.scatter(x1, y1, label = "Grupo 1", color = "red", marker = "^", s = 150);
plt.scatter(x2, y2, label = "Grupo 2", color = "green", marker = "X", s = 150);

## gráfico de linhas dentro do gráfico scatterplot
## o atributo color aceita cores hexadecimais
plt.plot(x1, y1, color = "#080808", linestyle = ":");
plt.plot(x2, y2, color = "#000000", linestyle = "--");

## plt.legend = coloca legenda no grafico
plt.legend();
plt.grid();
## plt.show();

## plt.savefig = salva o gráfico como imagem
## Essa função nao funciona no Google Colab
## PS: Funciona normalmente, mas o drive tem que estar montado conforme explicação feita nos exemplos finais
## Refiz essa mesma condição e coloquei para salvar no drive, após ele ser montado e deu tudo certo
## O exemplo esta no final desse documento
plt.savefig("figura.png", dpi = 1200);

# %%
## Estudo de caso - Crescimento da população Brasileira (1980 a 2016)
## Informações do DataSUS

## Montar o drive dentro do Google Colab (Executar somente uma vez. Após isso, o código deve ser comentado)
# from google.colab import drive

# drive.mount('/content/drive');

import matplotlib.pyplot as plt
import numpy as np

dados = open('/content/drive/My Drive/populacao_brasileira.csv').readlines();

x = [];
y = [];

for i in range(len(dados)):
  if i != 0:
    linha = dados[i].split(';');
    x.append(int(linha[0]));
    y.append(int(linha[1]));

title = 'Crescimento da população brasileira';
xlabel = 'Ano';
ylabel = 'População x 100.000.000';

plt.title(title);
plt.xlabel(xlabel);
plt.ylabel(ylabel);

plt.plot(x, y, color = 'black', linestyle = '--');
plt.bar(x, y, color = '#E4E4E4');
plt.grid();
plt.show();

# %%
## Estudo de caso - Crescimento da população Brasileira (1980 a 2016)
## Informações do DataSUS

## Montar o drive dentro do Google Colab (Executar somente uma vez. Após isso, o código deve ser comentado)
## Esse codigo deve ser executado toda vez que o Notebook for aberto
## Apos a execução, vai aparecer um link e logo abaixo, uma caixa para digitar uma senha
## Acesse o link e clique na conta Google que contém o arquivo desejado
## Automaticamente o sistema gera a senha pra voce sopiar e colar no campo solicitado
## O comando é o seguinte:

# from google.colab import drive

# drive.mount('/content/drive');

import matplotlib.pyplot as plt
import numpy as np

## Aqui voce importa os arquivos para a variável que deseja
## O arquivo populacao_brasileira.csv pode ser encontrado no link:
## https://drive.google.com/open?id=1Jj_pWYkI4FnVcCTXDa14pgN57xfP3SDX
dados = open('/content/drive/My Drive/Data Scientist/populacao_brasileira.csv').readlines();

x = [];
y = [];

for i in range(len(dados)):
  if i != 0:
    linha = dados[i].split(';');
    x.append(int(linha[0]));
    y.append(int(linha[1]));

title = 'Crescimento da população brasileira';
xlabel = 'Ano';
ylabel = 'População x 100.000.000';

plt.title(title);
plt.xlabel(xlabel);
plt.ylabel(ylabel);

plt.scatter(x, y, color = 'blue', marker = '.', s = 100);
plt.plot(x, y, color = 'black');

## plt.grid = coloca as linhas da grade no gráfico
plt.grid();
plt.show();
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
## Boxplot - Diagrama de caixa

import matplotlib.pyplot as plt
import random

vetor = [];

for i in range(10):
  num_aleatorio = random.randint(0, 5);
  vetor.append(num_aleatorio);

plt.title('Boxplot!')
plt.boxplot(vetor);
plt.show();

# %%
## O ponto de acesso ao drive ja foi montado anteriormente.
## Se nao tiver feito o passo anterior para realizar a montagem, terá que fazer aqui.

## DNA Bactéria
dados_entrada_bacteria = open('/content/drive/My Drive/Data Scientist/bacteria.fasta').read().replace('\n', '');
# dados_entrada_human = open('/content/drive/My Drive/Data Scientist/human.fasta').read().replace('\n', '');

dados_saida_bacteria = open('/content/drive/My Drive/Data Scientist/bacteria.html', 'w');
# dados_saida_human = open('/content/drive/My Drive/Data Scientist/human.html', 'w');

dicionario = {};

for i in ['A', 'T', 'C', 'G']:
  for j in ['A', 'T', 'C', 'G']:
    dicionario[i + j] = 0;

for i in range(len(dados_entrada_bacteria) - 1):
  dicionario[dados_entrada_bacteria[i] + dados_entrada_bacteria[i + 1]] += 1;

contador = 1;

for i in dicionario:
  transparencia = str(dicionario[i] / max(dicionario.values()));
  dados_saida_bacteria.write("<div style='width: 100px; height: 100px; border:1px solid #111; float: left; background-color: rgba(0, 255, 0, "+transparencia+"); color = #000'>"+i+"</div>");

  if contador % 4 == 0:
    dados_saida_bacteria.write("<div style='clear: both'><div>");
  
  contador += 1;

dados_saida_bacteria.close();

# %%
## O ponto de acesso ao drive ja foi montado anteriormente.
## Se nao tiver feito o passo anterior para realizar a montagem, terá que fazer aqui.

## DNA Humano
# dados_entrada_bacteria = open('/content/drive/My Drive/Data Scientist/bacteria.fasta').read().replace('\n', '');
dados_entrada_human = open('/content/drive/My Drive/Data Scientist/human.fasta').read().replace('\n', '');

# dados_saida_bacteria = open('/content/drive/My Drive/Data Scientist/bacteria.html', 'w');
dados_saida_human = open('/content/drive/My Drive/Data Scientist/human.html', 'w');

dicionario = {};

for i in ['A', 'T', 'C', 'G']:
  for j in ['A', 'T', 'C', 'G']:
    dicionario[i + j] = 0;

for i in range(len(dados_entrada_human) - 1):
  dicionario[dados_entrada_human[i] + dados_entrada_human[i + 1]] += 1;

contador = 1;

for i in dicionario:
  transparencia = str(dicionario[i] / max(dicionario.values()));
  dados_saida_human.write("<div style='width: 100px; height: 100px; border:1px solid #111; float: left;background-color: rgba(0, 0, 255, "+transparencia+"); color = #000'>"+i+"</div>");

  if contador % 4 == 0:
    dados_saida_human.write("<div style='clear: both'><div>");
  
  contador += 1;

dados_saida_human.close();

# %%
x1 = [1, 3, 5, 7, 9];
y1 = [2, 3, 7, 1, 0];

x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

title1 = "Gráfico Scatterplot em Python!";

## Titulo do Gráfico
plt.title(title1);

## Legenda dos eixos
plt.xlabel(eixoX);
plt.ylabel(eixoY);

## plt.scatter = grafico scatterplot
## atributo color altera a cor dos pontos no grafico
## marker = altera o marcador no grafico
## s = altera o tamanho do marcador
## linestyle = altera o estilo da linha
plt.scatter(x1, y1, label = "Grupo 1", color = "red", marker = "^", s = 150);
plt.scatter(x2, y2, label = "Grupo 2", color = "green", marker = "X", s = 150);

## gráfico de linhas dentro do gráfico scatterplot
## o atributo color aceita cores hexadecimais
plt.plot(x1, y1, color = "#080808", linestyle = ":");
plt.plot(x2, y2, color = "#000000", linestyle = "--");

## plt.legend = coloca legenda no grafico
plt.legend();
plt.grid();
## plt.show();

## plt.savefig = salva o gráfico como imagem
## Imagem salva utilizando o ponto de montagem do drive
plt.savefig('/content/drive/My Drive/Data Scientist/grafico.png', dpi = 1200);
